# %%
import pandas as pd

pd.options.display.max_rows = 10

# %%
df = pd.read_csv('Dataset/PSA_ADAS_W3_FC_2022-09-01_14-49_0054.MF4/Group_349.csv')

df[['_g_Infrastructure_CCR_NET_NetRunnablesClass_m_rteInputData_out_local.TChangeableMemPool._._._m_arrayPool._0_._elem._m_camData._m_objects._m_value._0_._m_dx', '_g_Infrastructure_CCR_NET_NetRunnablesClass_m_rteInputData_out_local.TChangeableMemPool._._._m_arrayPool._0_._elem._m_camData._m_objects._m_value._0_._m_dy']]

x = 0
y=0

print('x')
for row in range(0, 30000):
    dx = df['_g_Infrastructure_CCR_NET_NetRunnablesClass_m_rteInputData_out_local.TChangeableMemPool._._._m_arrayPool._0_._elem._m_camData._m_objects._m_value._0_._m_dx'].iloc[row]
    x = dx/10
    print(dx)

print('y')
for row in range(0, 50):
    dy = df['_g_Infrastructure_CCR_NET_NetRunnablesClass_m_rteInputData_out_local.TChangeableMemPool._._._m_arrayPool._0_._elem._m_camData._m_objects._m_value._0_._m_dy'].iloc[row]
# Out:
# x
# 4083
# 4083
# 4083
# 4083
# 4083
# 4070
# 4070
# 4070
# 4070
# 4070
# 4057
# 4057
# 4057
# 4057
# 4057
# 4044
# 4044
# 4044
# 4044
# 4044
# 4032
# 4032
# 4032
# 4032
# 4032
# 4019
# 4019
# 4019
# 4019
# 4019
# 4006
# 4006
# 4006
# 4006
# 4006
# 4006
# 4006
# 4006
# 4006
# 4006
# 3993
# 3993
# 3993
# 3993
# 3993
# 3980
# 3980
# 3980
# 3980
# 3980
# 3955
# 3955
# 3955
# 3955
# 3955
# 3955
# 3955
# 3955
# 3955
# 3955
# 3929
# 3929
# 3929
# 3929
# 3929
# 3916
# 3916
# 3916
# 3916
# 3916
# 3904
# 3904
# 3904
# 3904
# 3904
# 3891
# 3891
# 3891
# 3891
# 3891
# 3865
# 3865
# 3865
# 3865
# 3865
# 3852
# 3852
# 3852
# 3852
# 3852
# 3852
# 3852
# 3852
# 3852
# 3852
# 3827
# 3827
# 3827
# 3827
# 3827
# 3814
# 3814
# 3814
# 3814
# 3814
# 3788
# 3788
# 3788
# 3788
# 3788
# 3776
# 3776
# 3776
# 3776
# 3776
# 3763
# 3763
# 3763
# 3763
# 3763
# 3737
# 3737
# 3737
# 3737
# 3737
# 3724
# 3724
# 3724
# 3724
# 3724
# 3712
# 3712
# 3712
# 3712
# 3712
# 3699
# 3699
# 3699
# 3699
# 3699
# 3660
# 3660
# ...

# %%
df = pd.read_csv('Dataset/PSA_ADAS_W3_FC_2022-09-01_14-49_0054.MF4/Group_349.csv')

df[['_g_Infrastructure_CCR_NET_NetRunnablesClass_m_rteInputData_out_local.TChangeableMemPool._._._m_arrayPool._0_._elem._m_camData._m_objects._m_value._0_._m_dx', '_g_Infrastructure_CCR_NET_NetRunnablesClass_m_rteInputData_out_local.TChangeableMemPool._._._m_arrayPool._0_._elem._m_camData._m_objects._m_value._0_._m_dy']]

df
# Out:
#                 t  \
# 0        1.232097
# 1        1.242717
# 2        1.251795
# 3        1.262027
# 4        1.272959
# ...           ...
# 29867  299.996722
# 29868  300.007578
# 29869  300.016528
# 29870  300.027681
# 29871  300.036995
#
#        _g_Infrastructure_CCR_NET_NetRunnablesClass_m_rteInputData_out_local.TChangeableMemPool._._._m_arrayPool._0_._elem._m_camData._m_cameraTimeStamp  \
# 0                                                 136649
# 1                                                 136649
# 2                                                 136649
# 3                                                 136649
# 4                                                 136677
# ...                                                  ...
# 29867                                             435278
# 29868                                             435278
# 29869                                             435333
# 29870                                             435333
# ...
